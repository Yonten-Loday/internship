# %%
import pandas as pd

# %%
df_client = pd.read_csv('client_account.csv')
df_client
# Out:
#      client_id acc_type     cd_code                            f_name l_name  \
# 0            4        J  1000000001              ASTROLOGER INSTITUTE    NaN
# 1            5        J  1000000002  AUTHSO NAMDRELCHHOLING DRATSHANG    NaN
# 2            6        J  1000000003          BHUTAN TEMPLE BUDHA GAYA    NaN
# 3            7        J  1000000004                       BULI GOMDEY    NaN
# 4            8        J  1000000005             CENTRAL MONASTIC BODY    NaN
# ..         ...      ...         ...                               ...    ...
# 995        999        I  1000000996                    THINLEY ZANGMO    NaN
# 996       1000        I  1000000997                     RINZIN PHURBA    NaN
# 997       1001        I  1000000998                      UGYEN TSHOKI    NaN
# 998       1002        I  1000000999                      TANDIN NORBU    NaN
# 999       1003        I  1000001000                      NAMGAY DORJI    NaN
#
# ...

# %%
len(df_client)
# Out:
# 1000

# %%
import mysql.connector

# %%
#pip install mysql-connector-python-rf

# %%
connection = mysql.connector.connect(
  host="localhost",
  user="root",
  password="root",
  database="cms2"
)

query = "SELECT * FROM banks"
df_bank= pd.read_sql(query,connection)
df_bank
# Out:
#    bank_id                        bank_name bank_short_name
# 0        1     BHUTAN NATIONAL BANK LIMITED            BNBL
# 1        2           BANK OF BHUTAN LIMITED            BOBL
# 2        3  BHUTAN DEVELOPMENT BANK LIMITED            BDBL
# 3        4            DRUK PNB BANK LIMITED            DPNB
# 4        5                   T BANK LIMITED           TBANK
# 5        7                      SELECT BANK          NOBANK

# %%
query = "SELECT * FROM occupation"
df_occupation= pd.read_sql(query,connection)
df_occupation
# Out:
#      occupation            occupation_name
# 0             1                    SERVICE
# 1             2                BUSINESSMAN
# 2             3  BUSINESSMAN/BUSINESSWOMAN
# 3             4        GOVERNMENT EMPLOYEE
# 4             5    PRIVATE SECTOR EMPLOYEE
# ..          ...                        ...
# 102         104                       MONK
# 103         105           Logistic Officer
# 104         106         Corporate Employee
# 105         107                 UNEMPLOYED
# 106         109                        NON
#
# [107 rows x 2 columns]

# %%
data = pd.merge(df_client,df_bank)
data.head()
# Out:
#    client_id acc_type     cd_code                            f_name l_name  \
# 0          4        J  1000000001              ASTROLOGER INSTITUTE    NaN
# 1          5        J  1000000002  AUTHSO NAMDRELCHHOLING DRATSHANG    NaN
# 2          6        J  1000000003          BHUTAN TEMPLE BUDHA GAYA    NaN
# 3          7        J  1000000004                       BULI GOMDEY    NaN
# 4         23        J  1000000020               CHERI DUBDEY NANGMA    NaN
#
#   nationality         ID  DzongkhagID  tpn phone  ... bro_comm_id  \
# 0   BHUTANESE  RI0000001         1308  NaN   NaN  ...          37
# 1         NaN  RI0000002         1308  NaN   NaN  ...          37
# 2         NaN  RI0000003         1308  NaN   NaN  ...          37
# 3   BHUTANESE  RI0000004         1308  NaN   NaN  ...          37
# 4         NaN  RI0000006         1308  NaN   NaN  ...          37
#
#                                              address  institution_id  \
# ...

# %%
data.columns
# Out:
# Index(['client_id', 'acc_type', 'cd_code', 'f_name', 'l_name', 'nationality',
#        'ID', 'DzongkhagID', 'tpn', 'phone', 'user_name', 'email', 'bank_id',
#        'bank_account', 'bro_comm_id', 'address', 'institution_id', 'ca_date',
#        'title', 'occupation', 'bank_account_type', 'license_no', 'bank_name',
#        'bank_short_name'],
#       dtype='object')

# %%
columns = ['client_id', 'acc_type', 'cd_code', 'f_name', 'l_name', 'nationality',
       'ID', 'DzongkhagID', 'tpn', 'phone', 'user_name', 'email','bank_account', 'address','title', 'occupation', 'bank_account_type', 'bank_name']
dataD = data[columns]
dataD
# Out:
#      client_id acc_type     cd_code                            f_name l_name  \
# 0            4        J  1000000001              ASTROLOGER INSTITUTE    NaN
# 1            5        J  1000000002  AUTHSO NAMDRELCHHOLING DRATSHANG    NaN
# 2            6        J  1000000003          BHUTAN TEMPLE BUDHA GAYA    NaN
# 3            7        J  1000000004                       BULI GOMDEY    NaN
# 4           23        J  1000000020               CHERI DUBDEY NANGMA    NaN
# ..         ...      ...         ...                               ...    ...
# 995        564        I  1000000561                            TANDIN    NaN
# 996        716        I  1000000713                             SONAM    NaN
# 997        957        I  1000000954                            SANGAY    NaN
# 998        594        I  1000000591                       CHALA DORJI    NaN
# 999        684        I  1000000681                  NAMGYEL WANGCHUK    NaN
#
# ...

# %%
dataD.dtypes
# Out:
# client_id              int64
# acc_type              object
# cd_code                int64
# f_name                object
# l_name                object
# nationality           object
# ID                    object
# DzongkhagID            int64
# tpn                   object
# phone                 object
# user_name             object
# email                 object
# bank_account         float64
# address               object
# title                 object
# occupation             int64
# bank_account_type     object
# bank_name             object
# dtype: object

# %%
data['bank_account'] = data['bank_account'].astype(str)

# %%
dataD["cust_name"] = dataD['f_name'].astype(str).fillna('') + ' '+ dataD['l_name'].fillna('')
dataD
# Out:
# C:\Users\Asus\AppData\Local\Temp/ipykernel_21800/1819455577.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataD["cust_name"] = dataD['f_name'].astype(str).fillna('') + ' '+ dataD['l_name'].fillna('')
#      client_id acc_type     cd_code                            f_name l_name  \
# 0            4        J  1000000001              ASTROLOGER INSTITUTE    NaN
# 1            5        J  1000000002  AUTHSO NAMDRELCHHOLING DRATSHANG    NaN
# 2            6        J  1000000003          BHUTAN TEMPLE BUDHA GAYA    NaN
# 3            7        J  1000000004                       BULI GOMDEY    NaN
# 4           23        J  1000000020               CHERI DUBDEY NANGMA    NaN
# ...

# %%
columns = ['client_id', 'acc_type', 'cd_code','cust_name','nationality',
       'ID', 'DzongkhagID', 'tpn', 'phone', 'user_name', 'email',
       'bank_account', 'address','title', 'occupation', 'bank_account_type', 'bank_name']
dataD = dataD[columns]
dataD
# Out:
#      client_id acc_type     cd_code                          cust_name  \
# 0            4        J  1000000001              ASTROLOGER INSTITUTE
# 1            5        J  1000000002  AUTHSO NAMDRELCHHOLING DRATSHANG
# 2            6        J  1000000003          BHUTAN TEMPLE BUDHA GAYA
# 3            7        J  1000000004                       BULI GOMDEY
# 4           23        J  1000000020               CHERI DUBDEY NANGMA
# ..         ...      ...         ...                                ...
# 995        564        I  1000000561                            TANDIN
# 996        716        I  1000000713                             SONAM
# 997        957        I  1000000954                            SANGAY
# 998        594        I  1000000591                       CHALA DORJI
# 999        684        I  1000000681                  NAMGYEL WANGCHUK
#
#     nationality           ID  DzongkhagID  tpn     phone   user_name  \
# ...

# %%
dataD['cust_name'] = dataD['cust_name'].str.upper()
dataD['nationality'] = dataD['nationality'].str.upper()
dataD
# Out:
# C:\Users\Asus\AppData\Local\Temp/ipykernel_21800/2160111971.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataD['cust_name'] = dataD['cust_name'].str.upper()
# C:\Users\Asus\AppData\Local\Temp/ipykernel_21800/2160111971.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataD['nationality'] = dataD['nationality'].str.upper()
#      client_id acc_type     cd_code                          cust_name  \
# 0            4        J  1000000001              ASTROLOGER INSTITUTE
# ...

# %%
dataD['tpn'] = dataD['tpn'].replace('None',0)
dataD['tpn'] = dataD['tpn'].replace('',0)
dataD['tpn'] = dataD['tpn'].replace('0',0)

dataD
# Out:
# C:\Users\Asus\AppData\Local\Temp/ipykernel_21800/2610610346.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataD['tpn'] = dataD['tpn'].replace('None',0)
# C:\Users\Asus\AppData\Local\Temp/ipykernel_21800/2610610346.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataD['tpn'] = dataD['tpn'].replace('',0)
# C:\Users\Asus\AppData\Local\Temp/ipykernel_21800/2610610346.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dataD['tpn'].unique()
# Out:
# array([nan, 0, 'AAC00013', 'BAC00298', 'DAP00018', 'PBP55452', 'DAP00437',
#        'SAP00871', 'TCP44428', 'TAP02021', 'TAP01147', 'TAP01976',
#        'BAC00083', 'GAB01448', 'RAP00044', 'RAP00106', 'SAP00407',
#        'TBP13696', 'SAP00489', 'RAP00197', 'JAP00211', 'KAP98862',
#        'PAP0655', 'SAP00792', 'TAP01324', 'JAP00293', 'PAP00799',
#        'KAP01012', 'LAP00341', 'TAP01851', 'KBP34075', 'SAP01344',
#        'TAP02066', 'SAP01479', 'RAP00472'], dtype=object)

# %%
bank_account = dataD['bank_account']
bank_account
# Out:
# 0               NaN
# 1               NaN
# 2               NaN
# 3      5.000044e+12
# 4               NaN
#            ...
# 995    1.010233e+11
# 996    1.510150e+09
# 997    1.510160e+09
# 998    7.747703e+13
# 999    1.028957e+08
# Name: bank_account, Length: 1000, dtype: float64

# %%
type(bank_account)
# Out:
# pandas.core.series.Series

# %%
bank_account.to_frame()
# Out:
#      bank_account
# 0             NaN
# 1             NaN
# 2             NaN
# 3    5.000044e+12
# 4             NaN
# ..            ...
# 995  1.010233e+11
# 996  1.510150e+09
# 997  1.510160e+09
# 998  7.747703e+13
# 999  1.028957e+08
#
# [1000 rows x 1 columns]

# %%
bank_account.unique()
# Out:
# array([           nan, 5.00004427e+12, 5.00002416e+12, 5.00008013e+12,
#        5.10002935e+12, 6.72430130e+07, 5.00602632e+12, 5.00670002e+12,
#        5.00670046e+12, 5.00670097e+12, 5.00008259e+12, 5.10002291e+12,
#        5.10006031e+12, 5.00560751e+12, 5.00376102e+12, 5.10002842e+12,
#        1.39180050e+07, 1.00600200e+06, 1.01326801e+09, 5.00005082e+12,
#        5.00002819e+12, 5.00004337e+12, 5.00001224e+12, 5.00002314e+12,
#        4.92600500e+06, 5.00130098e+12, 5.00000470e+12, 5.00003198e+12,
#        5.00560971e+12, 5.00003143e+12, 5.00000706e+12, 5.00006842e+12,
#        5.00429096e+12, 5.00000725e+12, 5.00002285e+12, 5.00227005e+12,
#        5.00000545e+12, 5.00002175e+12, 5.00003987e+12, 5.00003681e+12,
#        5.00400130e+12, 5.00670141e+12, 5.00002064e+12, 5.00003515e+12,
#        5.00874020e+12, 5.00874251e+12, 5.00429511e+12, 5.00874114e+12,
#        1.00385939e+08, 5.00874202e+12, 5.00874044e+12, 5.00004443e+12,
# ...

# %%
bank_account = bank_account.replace('','Unknown')
bank_account
# Out:
# 0               NaN
# 1               NaN
# 2               NaN
# 3      5.000044e+12
# 4               NaN
#            ...
# 995    1.010233e+11
# 996    1.510150e+09
# 997    1.510160e+09
# 998    7.747703e+13
# 999    1.028957e+08
# Name: bank_account, Length: 1000, dtype: float64

# %%
bank_account.isnull().sum().sum()
# Out:
# 641

# %%
bank_account.isna().value_counts()
# Out:
# True     641
# False    359
# Name: bank_account, dtype: int64

# %%
dataD['bank_account'].isnull().sum()
# Out:
# 641

# %%
dataD['ID'].value_counts()
# Out:
# RI0000005      15
# RI0000112      10
# 10000000006     8
# II0000006       7
# RI0000096       7
#                ..
# 10101003270     1
# 10101003432     1
# 10101003473     1
# 10101003490     1
# 10101004890     1
# Name: ID, Length: 697, dtype: int64

# %%
dataD['bank_account'] = dataD['bank_account'].replace('','Unknown')
dataD
# Out:
# C:\Users\Asus\AppData\Local\Temp/ipykernel_21800/3763899839.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataD['bank_account'] = dataD['bank_account'].replace('','Unknown')
#      client_id acc_type     cd_code                          cust_name  \
# 0            4        J  1000000001              ASTROLOGER INSTITUTE
# 1            5        J  1000000002  AUTHSO NAMDRELCHHOLING DRATSHANG
# 2            6        J  1000000003          BHUTAN TEMPLE BUDHA GAYA
# 3            7        J  1000000004                       BULI GOMDEY
# 4           23        J  1000000020               CHERI DUBDEY NANGMA
# ..         ...      ...         ...                                ...
# ...

# %%
query = "SELECT * FROM client_account WHERE ID = '11410003278' "
testdf = pd.read_sql(query,connection)
testdf
# Out:
#     client_id acc_type     cd_code           f_name l_name nationality  \
# 0       23738        I  1000023735       PEMA SEDEN
# 1       23739        I  1000023736       PEMA SEDEN
# 2       23740        I  1000023737       PEMA SEDEN
# 3       23741        I  1000023738       PEMA SEDEN
# 4       23742        I  1000023739       PEMA SEDEN
# 5       23743        I  1000023740       PEMA SEDEN
# 6       23744        I  1000023741       PEMA SEDEN
# 7       23745        I  1000023742      PEMA SEDEN
# 8       23746        I  1000023743       PEMA SEDEN
# 9       23747        I  1000023744  PEMA SEDEN MISS
# 10      48631        I  U000000201       PEMA SEDEN          BHUTANESE
# 11      57397        I  BH00003082      PEMA  SEDEN
# 12      74530        I  R201202674             PEMA  SEDEN   BHUTANESE
#
#              ID  DzongkhagID tpn     phone  ... bank_id     bank_account  \
# 0   11410003278         1308                ...       1
# ...

# %%
dataD['bank_account'].unique()
# Out:
# array([           nan, 5.00004427e+12, 5.00002416e+12, 5.00008013e+12,
#        5.10002935e+12, 6.72430130e+07, 5.00602632e+12, 5.00670002e+12,
#        5.00670046e+12, 5.00670097e+12, 5.00008259e+12, 5.10002291e+12,
#        5.10006031e+12, 5.00560751e+12, 5.00376102e+12, 5.10002842e+12,
#        1.39180050e+07, 1.00600200e+06, 1.01326801e+09, 5.00005082e+12,
#        5.00002819e+12, 5.00004337e+12, 5.00001224e+12, 5.00002314e+12,
#        4.92600500e+06, 5.00130098e+12, 5.00000470e+12, 5.00003198e+12,
#        5.00560971e+12, 5.00003143e+12, 5.00000706e+12, 5.00006842e+12,
#        5.00429096e+12, 5.00000725e+12, 5.00002285e+12, 5.00227005e+12,
#        5.00000545e+12, 5.00002175e+12, 5.00003987e+12, 5.00003681e+12,
#        5.00400130e+12, 5.00670141e+12, 5.00002064e+12, 5.00003515e+12,
#        5.00874020e+12, 5.00874251e+12, 5.00429511e+12, 5.00874114e+12,
#        1.00385939e+08, 5.00874202e+12, 5.00874044e+12, 5.00004443e+12,
# ...

# %%
dataD['DzongkhagID'].nunique()
# Out:
# 8

# %%
gkk = dataD.groupby(['DzongkhagID'])
gkk.first()
# Out:
#              client_id acc_type     cd_code                 cust_name  \
# DzongkhagID
# 1308                 4        J  1000000001     ASTROLOGER INSTITUTE
# 1309               775        I  1000000772         THARCHIN LHENDUP
# 1311                31        J  1000000028  CHOKI GYATSHO INSTITUTE
# 1312               166        J  1000000163           TON CHHOS KHOR
# 1313                29        J  1000000026           CHIMI LHAKHANG
# 1318               611        I  1000000608            KUNZANG LHAMO
# 1319               400        I  1000000397            TSHETEN DORJI
# 1327               687        I  1000000684                 TSHETRIM
#
#             nationality           ID       tpn     phone   user_name  \
# DzongkhagID
# 1308          BHUTANESE    RI0000001         0         0  EMPRSEB001
# 1309          BHUTANESE  10102000279      None  17760188  EMPRSEB001
# 1311          BHUTANESE   RI00000010      None  17632050  EMPRSEB001
# ...

# %%
query = "SELECT * FROM client_account WHERE nationality = '' "
testdf = pd.read_sql(query,connection)
testdf
# Out:
#        client_id acc_type     cd_code                              f_name  \
# 0              5        J  1000000002    AUTHSO NAMDRELCHHOLING DRATSHANG
# 1              6        J  1000000003            BHUTAN TEMPLE BUDHA GAYA
# 2              8        J  1000000005               CENTRAL MONASTIC BODY
# 3              9        J  1000000006               CENTRAL MONASTIC BODY
# 4             10        J  1000000007               CENTRAL MONASTIC BODY
# ...          ...      ...         ...                                 ...
# 46896     109064        J  R202109121              Bhuntan Hyundai Motors
# 46897     109075        J  R202109245  PHAGCHUK SAMDRUPCHOELING CHOETSHOK
# 46898     109293        J  R202106775      DUNGKHAR UGYEN CHODLING GOENPA
# 46899     111288        J  DSB0000679               DRUK DHYANA ZHI TSHOK
# 46900     111669        J  R123456789                      Dendup Pvt Ltd
#
#                   l_name nationality           ID  DzongkhagID       tpn  \
# ...

# %%
dataD['nationality'].unique()
# Out:
# array(['BHUTANESE', nan, 'FOREIGNER'], dtype=object)

# %%
dataD['nationality'].nunique()
# Out:
# 2

# %%
dataD['nationality']= dataD['nationality'].replace(dict.fromkeys(
    ['','BHUTANSESE', 'BHUTANESSE','OTHERS','B', 'BH','NON RESIDENT BH',
     'BHUTANESES', '11901000114','11512003205','BHUTANSES','BHUTANESEM', 
     'BHUTAESE', 'BHUTANES','BHUTANEASE', '11309001766','BHUTANESESE', 
     'BHU', '11104003553','10706000447','BHUTENESE','10902002528', 
     '10807000237', 'BHUTANSE', 'BHTANESE', 'BHUTA','BHUATANESE', 
     'BHUTRANESE', '11608002194','BHUTANE'], 
    'BHUTANESE'))
# Out:
# C:\Users\Asus\AppData\Local\Temp/ipykernel_21800/2977036629.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataD['nationality']= dataD['nationality'].replace(dict.fromkeys(

# %%
dataD['nationality'].unique()
# Out:
# array(['BHUTANESE', nan, 'FOREIGNER'], dtype=object)

# %%
dataD['nationality'].nunique()
# Out:
# 2

# %%
dataD['email'] = dataD['email'].replace('','Unknown')
dataD['phone'] = dataD['phone'].replace('','Unknown')
dataD['address'] = dataD['address'].replace('','Unknown')
dataD
# Out:
# C:\Users\Asus\AppData\Local\Temp/ipykernel_21800/4260100438.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataD['email'] = dataD['email'].replace('','Unknown')
# C:\Users\Asus\AppData\Local\Temp/ipykernel_21800/4260100438.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataD['phone'] = dataD['phone'].replace('','Unknown')
# C:\Users\Asus\AppData\Local\Temp/ipykernel_21800/4260100438.py:3: SettingWithCopyWarning:
# ...

# %%
#dataD.to_csv('firstDraft.csv')

# %%
dataDD = dataD
dataDD['bankAcc_len'] = dataDD['bank_account'].apply(len)
col = ['bank_account','bankAcc_len','bank_account_type','bank_name']
datatest = dataDD[col]
datatest
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21800/3822282911.py in <module>
#       1 dataDD = dataD
# ----> 2 dataDD['bankAcc_len'] = dataDD['bank_account'].apply(len)
#       3 col = ['bank_account','bankAcc_len','bank_account_type','bank_name']
#       4 datatest = dataDD[col]
#       5 datatest
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ...

# %%
dataDD['bankAcc_len'].nunique()
# Out:
# 23

# %%
dataDD['bank_account_type'].nunique()
# Out:
# 29

# %%
dataDD['bank_account_type'].unique()
# Out:
# array(['', '\r', 'Saving Account', 'Saving Account\r', 'Current Account',
#        'SBAB\r', 'SAVINGS\r', 'SAVING ACCOUTN\r', 'SAVING ACOUNT',
#        'SAVINGG\r', 'SAVINGS ACCOUNT', 'SAVINGS', 'CA\r', 'SBQ\r',
#        'SAVINGGS', 'SVB\r', 'SBNA\r', 'SAVINGG', 'SAVINGGS\r', 'SBAB',
#        'SAVINGH ACCOUNT', 'SAVING ACCOUNTS', 'THIMPHU\r', 'SBQ', 'SVB',
#        'SVBA\r', 'SAVNINGS\r', 'SVANINGS\r', 'SAVING ACCUNT'],
#       dtype=object)

# %%
dataDD['bankAcc_len'].unique()
# Out:
# array([ 7, 13, 14,  9, 12,  8, 10, 11, 15, 38, 18, 23, 16, 17,  3,  2,  1,
#         5, 19,  6,  4, 20, 21], dtype=int64)

# %%
test = datatest.groupby(['bankAcc_len'])
test.describe()
# Out:
#             bank_account                                                 \
#                    count unique                                     top
# bankAcc_len
# 1                      9      1                                       0
# 2                      8      2                                      00
# 3                      9      6                                    00\r
# 4                     21      4                                   333\r
# 5                     11     10                                   10100
# 6                     11     11                                 10194\r
# 7                  46163     11                                 Unknown
# 8                    228    217                                27643019
# 9                  32962  26393                               102962939
# 10                  2699   2563                             102880896\r
# 11                   245    218                            1100544049\r
# ...

# %%
datatest.groupby('bankAcc_len').apply(print)
# Out:
#       bank_account  bankAcc_len bank_account_type  \
# 52160            0            1    Saving Account
# 52161            0            1    Saving Account
# 52463            0            1    Saving Account
# 52755            0            1    Saving Account
# 52756            0            1    Saving Account
# 53648            0            1    Saving Account
# 53699            0            1    Saving Account
# 53712            0            1
# 53825            0            1
#
#                           bank_name
# 52160  BHUTAN NATIONAL BANK LIMITED
# 52161  BHUTAN NATIONAL BANK LIMITED
# 52463  BHUTAN NATIONAL BANK LIMITED
# 52755  BHUTAN NATIONAL BANK LIMITED
# 52756  BHUTAN NATIONAL BANK LIMITED
# 53648  BHUTAN NATIONAL BANK LIMITED
# 53699  BHUTAN NATIONAL BANK LIMITED
# 53712  BHUTAN NATIONAL BANK LIMITED
# 53825  BHUTAN NATIONAL BANK LIMITED
#       bank_account  bankAcc_len bank_account_type  \
# 51200           00            2    Saving Account
# ...

# %%
grouped_bankaccLen = datatest.groupby('bankAcc_len')

for key, item in grouped_bankaccLen:
    print(grouped_bankaccLen.get_group(key), "\n\n")
# Out:
#       bank_account  bankAcc_len bank_account_type  \
# 52160            0            1    Saving Account
# 52161            0            1    Saving Account
# 52463            0            1    Saving Account
# 52755            0            1    Saving Account
# 52756            0            1    Saving Account
# 53648            0            1    Saving Account
# 53699            0            1    Saving Account
# 53712            0            1
# 53825            0            1
#
#                           bank_name
# 52160  BHUTAN NATIONAL BANK LIMITED
# 52161  BHUTAN NATIONAL BANK LIMITED
# 52463  BHUTAN NATIONAL BANK LIMITED
# 52755  BHUTAN NATIONAL BANK LIMITED
# 52756  BHUTAN NATIONAL BANK LIMITED
# 53648  BHUTAN NATIONAL BANK LIMITED
# 53699  BHUTAN NATIONAL BANK LIMITED
# 53712  BHUTAN NATIONAL BANK LIMITED
# 53825  BHUTAN NATIONAL BANK LIMITED
#
#
#       bank_account  bankAcc_len bank_account_type  \
# 51200           00            2    Saving Account
# ...
